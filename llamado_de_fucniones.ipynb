# %%
import funciones as fs

# %%
df = fs.leer_dataframe("Berlin_Alemania.csv")
df
# Out:
#        Unnamed: 0                   id       scrape_id  \
# 0               0              2084992  20241221052002
# 1               1  1123383729460847373  20241221052002
# 2               2  1205255838613758737  20241221052002
# 3               3              8164759  20241221052002
# 4               4             18836877  20241221052002
# ...           ...                  ...             ...
# 13979       13979  1066742710842868324  20241221052002
# 13980       13980   882524735229064604  20241221052002
# 13981       13981  1172288594718636022  20241221052002
# 13982       13982  1233927040956879330  20241221052002
# 13983       13983  1285513092900098347  20241221052002
#
#                                                     name  \
# 0       Nice and cozy apartment in Kreuzberg, Graefekiez
# 1      Furnished room in well equipped serviced apart...
# 2         Luxurous game room with private bath in X-Berg
# 3                           Beautiful single-room studio
# ...

# %%
df = df.drop(columns=["Unnamed: 0"]) #eliminar columna sobrante

# %%
df = fs.sustituir_valores_nulos(df) #sustituir nulos
df
# Out:
#                         id    host_id  host_total_listings_count  longitude  \
# 0                  2084992    6302373                        1.0  13.414800
# 1      1123383729460847373  206488801                        7.0  13.350000
# 2      1205255838613758737   50009901                        1.0  13.415324
# 3                  8164759   42115726                        3.0  13.357780
# 4                 18836877  131184702                        1.0  13.420490
# ...                    ...        ...                        ...        ...
# 13979  1066742710842868324  125006999                        3.0  13.460553
# 13980   882524735229064604  449692327                       59.0  13.375470
# 13981  1172288594718636022  570785536                        6.0  13.444353
# 13982  1233927040956879330    3893392                        2.0  13.440550
# 13983  1285513092900098347   21907458                        1.0  13.344286
#
# ...

# %%
fs.identificar_nulos(df) #contar si funcionó
# Out:
# ('Valores nulos por columna',
#  id                                              0
#  host_id                                         0
#  host_total_listings_count                       0
#  longitude                                       0
#  bathrooms                                       0
#  beds                                            0
#  minimum_nights                                  0
#  minimum_minimum_nights                          0
#  minimum_maximum_nights                          0
#  minimum_nights_avg_ntm                          0
#  availability_60                                 0
#  availability_365                                0
#  number_of_reviews_ltm                           0
#  review_scores_rating                            0
#  review_scores_cleanliness                       0
#  review_scores_communication                     0
#  review_scores_value                             0
#  calculated_host_listings_count_entire_homes     0
# ...

# %%
data_sin_atipicos= fs.identificar_valores_atipicos2(df)
# Out:
# id                                                 0
# host_id                                            0
# host_total_listings_count                       1955
# longitude                                        565
# bathrooms                                       1054
# beds                                            1102
# minimum_nights                                    42
# minimum_minimum_nights                            39
# minimum_maximum_nights                            11
# minimum_nights_avg_ntm                            41
# availability_60                                    0
# availability_365                                   0
# number_of_reviews_ltm                           1812
# review_scores_rating                            1105
# review_scores_cleanliness                       1082
# review_scores_communication                      720
# review_scores_value                             1104
# calculated_host_listings_count_entire_homes     2129
# ...

# %%
fs.identificar_nulos(data_sin_atipicos) #consultar si ya no hay valores atipicos
# Out:
# ('Valores nulos por columna',
#  name                                            0
#  host_is_superhost                               0
#  host_identity_verified                          0
#  room_type                                       0
#  has_availability                                0
#  instant_bookable                                0
#  description                                     0
#  host_name                                       0
#  host_has_profile_pic                            0
#  property_type                                   0
#  price                                           0
#  license                                         0
#  id                                              0
#  host_id                                         0
#  host_total_listings_count                       0
#  longitude                                       0
#  bathrooms                                       0
#  beds                                            0
# ...

# %%
data_sin_atipicos.to_csv("Berlin_procesado.csv") #pasar a un nuevo csv
